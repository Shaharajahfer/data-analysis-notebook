# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
crime = pd.read_csv('Crime_Data_from_2020_to_2024_20260414.csv')

# %% [markdown]
# # Understand and clean Data

# %%
crime.head(10)
# Out:
#        DR_NO                Date Rptd                 DATE OCC  TIME OCC  \
# 0  211507896  2021 Apr 11 12:00:00 AM  2020 Nov 07 12:00:00 AM       845
# 1  201516622  2020 Oct 21 12:00:00 AM  2020 Oct 18 12:00:00 AM      1845
# 2  240913563  2024 Dec 10 12:00:00 AM  2020 Oct 30 12:00:00 AM      1240
# 3  210704711  2020 Dec 24 12:00:00 AM  2020 Dec 24 12:00:00 AM      1310
# 4  201418201  2020 Oct 03 12:00:00 AM  2020 Sep 29 12:00:00 AM      1830
# 5  240412063  2024 Dec 11 12:00:00 AM  2020 Nov 11 12:00:00 AM      1210
# 6  240317069  2024 Dec 16 12:00:00 AM  2020 Apr 16 12:00:00 AM      1350
# 7  201115217  2020 Oct 29 12:00:00 AM  2020 Jul 07 12:00:00 AM      1400
# 8  241708596  2024 Apr 20 12:00:00 AM  2020 Mar 02 12:00:00 AM      1200
# 9  242113813  2024 Dec 18 12:00:00 AM  2020 Sep 01 12:00:00 AM       900
#
#    AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    15  N Hollywood         1502         2     354
# 1    15  N Hollywood         1521         1     230
# 2     9     Van Nuys          933         2     354
# 3     7     Wilshire          782         1     331
# 4    14      Pacific         1454         1     420
# 5     4   Hollenbeck          429         2     354
# 6     3    Southwest          396         2     354
# 7    11    Northeast         1133         2     812
# 8    17   Devonshire         1729         2     354
# 9    21      Topanga         2196         2     354
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC  Invest Cont
# 2                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC  Invest Cont
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC  Invest Cont
# 5                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 6                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 7  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...  ...     AO  Adult Other
# 8                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 9                                  THEFT OF IDENTITY  ...     IC  Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    354.0      NaN       NaN      NaN
# 1    230.0      NaN       NaN      NaN
# 2    354.0      NaN       NaN      NaN
# 3    331.0      NaN       NaN      NaN
# 4    420.0      NaN       NaN      NaN
# 5    354.0      NaN       NaN      NaN
# 6    354.0      NaN       NaN      NaN
# 7    812.0    860.0       NaN      NaN
# 8    354.0      NaN       NaN      NaN
# 9    354.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   7800    BEEMAN                       AV          NaN  34.2124 -118.4092
# 1           ATOLL                        AV     N  GAULT  34.1993 -118.4203
# 2  14600    SYLVAN                       ST          NaN  34.1847 -118.4509
# 3   6000    COMEY                        AV          NaN  34.0339 -118.3747
# 4                   4700    LA VILLA MARINA          NaN  33.9813 -118.4350
# 5   5300    CRONUS                       ST          NaN  34.0830 -118.1678
# 6    900 W  40TH                         PL          NaN  34.0100 -118.2900
# 7   3000    ACRESITE                     ST          NaN  34.1107 -118.2589
# 8  17700    SIMONDS                      ST          NaN  34.2763 -118.5210
# 9  20900    MARMORA                      ST          NaN  34.1493 -118.5886
#
# [10 rows x 28 columns]

# %%
crime.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
crime.shape
# Out:
# (1004894, 28)

# %%
crime.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
crime.isna().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151598
# Vict Age                0
# Vict Sex           144631
# Vict Descent       144643
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677678
# Weapon Desc        677678
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935740
# Crm Cd 3          1002580
# Crm Cd 4          1004830
# LOCATION                0
# Cross Street       850666
# LAT                     0
# LON                     0
# dtype: int64

# %%
df = crime.drop(labels=['Mocodes', 'Weapon Used Cd', 'Weapon Desc', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street'], axis = 1
               )
df
# Out:
#              DR_NO                Date Rptd                 DATE OCC  \
# 0        211507896  2021 Apr 11 12:00:00 AM  2020 Nov 07 12:00:00 AM
# 1        201516622  2020 Oct 21 12:00:00 AM  2020 Oct 18 12:00:00 AM
# 2        240913563  2024 Dec 10 12:00:00 AM  2020 Oct 30 12:00:00 AM
# 3        210704711  2020 Dec 24 12:00:00 AM  2020 Dec 24 12:00:00 AM
# 4        201418201  2020 Oct 03 12:00:00 AM  2020 Sep 29 12:00:00 AM
# ...            ...                      ...                      ...
# 1004889  240710284  2024 Jul 24 12:00:00 AM  2024 Jul 23 12:00:00 AM
# 1004890  240104953  2024 Jan 15 12:00:00 AM  2024 Jan 15 12:00:00 AM
# 1004891  240410786  2024 Oct 14 12:00:00 AM  2024 Oct 11 12:00:00 AM
# 1004892  240309674  2024 Apr 24 12:00:00 AM  2024 Apr 24 12:00:00 AM
# 1004893  240910892  2024 Aug 13 12:00:00 AM  2024 Aug 12 12:00:00 AM
#
#          TIME OCC  AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0             845    15  N Hollywood         1502         2     354
# 1            1845    15  N Hollywood         1521         1     230
# 2            1240     9     Van Nuys          933         2     354
# 3            1310     7     Wilshire          782         1     331
# 4            1830    14      Pacific         1454         1     420
# ...           ...   ...          ...          ...       ...     ...
# 1004889      1400     7     Wilshire          788         1     510
# 1004890       100     1      Central          101         2     745
# 1004891      2330     4   Hollenbeck          421         1     341
# 1004892      1500     3    Southwest          358         1     230
# 1004893      2300     9     Van Nuys          914         1     510
#
#                                                Crm Cd Desc  ...  Vict Sex  \
# 0                                        THEFT OF IDENTITY  ...         M
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...         M
# 2                                        THEFT OF IDENTITY  ...         M
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...         F
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...         M
# ...                                                    ...  ...       ...
# 1004889                                   VEHICLE - STOLEN  ...       NaN
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...         X
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...         M
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...         F
# 1004893                                   VEHICLE - STOLEN  ...       NaN
#
#         Vict Descent Premis Cd             Premis Desc Status  Status Desc  \
# 0                  H     501.0  SINGLE FAMILY DWELLING     IC  Invest Cont
# 1                  H     102.0                SIDEWALK     IC  Invest Cont
# 2                  W     501.0  SINGLE FAMILY DWELLING     IC  Invest Cont
# 3                  A     101.0                  STREET     IC  Invest Cont
# 4                  H     103.0                   ALLEY     IC  Invest Cont
# ...              ...       ...                     ...    ...          ...
# 1004889          NaN     101.0                  STREET     IC  Invest Cont
# 1004890            X     503.0                   HOTEL     IC  Invest Cont
# 1004891            B     210.0    RESTAURANT/FAST FOOD     IC  Invest Cont
# 1004892            W     102.0                SIDEWALK     IC  Invest Cont
# 1004893          NaN     108.0             PARKING LOT     IC  Invest Cont
#
#         Crm Cd 1                                  LOCATION      LAT       LON
# 0          354.0   7800    BEEMAN                       AV  34.2124 -118.4092
# 1          230.0           ATOLL                        AV  34.1993 -118.4203
# 2          354.0  14600    SYLVAN                       ST  34.1847 -118.4509
# 3          331.0   6000    COMEY                        AV  34.0339 -118.3747
# 4          420.0                   4700    LA VILLA MARINA  33.9813 -118.4350
# ...          ...                                       ...      ...       ...
# 1004889    510.0   4000 W  23RD                         ST  34.0362 -118.3284
# 1004890    745.0   1300 W  SUNSET                       BL  34.0685 -118.2460
# 1004891    341.0   1700    ALBION                       ST  34.0675 -118.2240
# 1004892    230.0           FLOWER                       ST  34.0215 -118.2868
# 1004893    510.0   6900    VESPER                       AV  34.1961 -118.4510
#
# [1004894 rows x 21 columns]

# %%
df.sort_values(by = 'Date Rptd')
# Out:
#             DR_NO                Date Rptd                 DATE OCC  TIME OCC  \
# 178688  201308923  2020 Apr 01 12:00:00 AM  2020 Apr 01 12:00:00 AM       600
# 119752  200908066  2020 Apr 01 12:00:00 AM  2020 Mar 30 12:00:00 AM       150
# 178728  200109965  2020 Apr 01 12:00:00 AM  2020 Apr 01 12:00:00 AM      1145
# 112835  201308914  2020 Apr 01 12:00:00 AM  2020 Mar 15 12:00:00 AM      1900
# 163301  200508222  2020 Apr 01 12:00:00 AM  2020 Mar 31 12:00:00 AM      2300
# ...           ...                      ...                      ...       ...
# 923065  251404290  2025 Mar 16 12:00:00 AM  2024 Dec 21 12:00:00 AM      2200
# 982937  251404291  2025 Mar 16 12:00:00 AM  2024 Dec 20 12:00:00 AM      1000
# 774025  252004245  2025 Mar 17 12:00:00 AM  2023 Mar 01 12:00:00 AM      1250
# 234907  252004244  2025 Mar 17 12:00:00 AM  2021 Feb 01 12:00:00 AM         1
# 277139  252004250  2025 Mar 28 12:00:00 AM  2021 Oct 13 12:00:00 AM      1000
#
#         AREA AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 178688    13    Newton         1333         2     626
# 119752     9  Van Nuys          919         1     440
# 178728     1   Central          139         1     440
# 112835    13    Newton         1341         1     420
# 163301     5    Harbor          526         1     330
# ...      ...       ...          ...       ...     ...
# 923065    14   Pacific         1407         1     330
# 982937    14   Pacific         1462         1     440
# 774025    20   Olympic         2033         2     940
# 234907    20   Olympic         2097         2     668
# 277139    20   Olympic         2069         2     649
#
#                                             Crm Cd Desc  ...  Vict Sex  \
# 178688                INTIMATE PARTNER - SIMPLE ASSAULT  ...         M
# 119752               THEFT PLAIN - PETTY ($950 & UNDER)  ...         M
# 178728               THEFT PLAIN - PETTY ($950 & UNDER)  ...         F
# 112835  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...       NaN
# 163301                            BURGLARY FROM VEHICLE  ...         M
# ...                                                 ...  ...       ...
# 923065                            BURGLARY FROM VEHICLE  ...         M
# 982937               THEFT PLAIN - PETTY ($950 & UNDER)  ...         F
# 774025                                        EXTORTION  ...         F
# 234907       EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)  ...         X
# 277139                 DOCUMENT FORGERY / STOLEN FELONY  ...         X
#
#        Vict Descent Premis Cd                                   Premis Desc  \
# 178688            B     502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 119752            O     123.0                  PARKING UNDERGROUND/BUILDING
# 178728            H     102.0                                      SIDEWALK
# 112835          NaN     101.0                                        STREET
# 163301            H     101.0                                        STREET
# ...             ...       ...                                           ...
# 923065            W     707.0                                GARAGE/CARPORT
# 982937            O     504.0                               OTHER RESIDENCE
# 774025            A     501.0                        SINGLE FAMILY DWELLING
# 234907            X     217.0                              AUTO REPAIR SHOP
# 277139            X     502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
#
#        Status   Status Desc Crm Cd 1                                 LOCATION  \
# 178688     AA  Adult Arrest    626.0  1000 E  28TH                         ST
# 119752     IC   Invest Cont    440.0  7100    WOODMAN                      AV
# 178728     IC   Invest Cont    440.0   700    TRACTION                     AV
# 112835     IC   Invest Cont    420.0  3800 S  GRAND                        AV
# 163301     IC   Invest Cont    330.0                                        G
# ...       ...           ...      ...                                      ...
# 923065     IC   Invest Cont    330.0  3600    JASMINE                      AV
# 982937     IC   Invest Cont    440.0                                  LINCOLN
# 774025     IC   Invest Cont    940.0   700 S  HOBART                       BL
# 234907     IC   Invest Cont    668.0  1800 W  WASHINGTON                   BL
# 277139     IC   Invest Cont    649.0  1100 S  WESTMORELAND                 AV
#
#             LAT       LON
# 178688  34.0175 -118.2574
# 119752  34.1994 -118.4313
# 178728  34.0457 -118.2364
# 112835  34.0152 -118.2793
# 163301  33.7785 -118.2636
# ...         ...       ...
# 923065  34.0260 -118.4052
# 982937  33.9676 -118.4276
# 774025  34.0597 -118.3053
# 234907  34.0400 -118.2974
# 277139  34.0508 -118.2891
#
# [1004894 rows x 21 columns]

# %%
df.dtypes
# Out:
# DR_NO             int64
# Date Rptd        object
# DATE OCC         object
# TIME OCC          int64
# AREA              int64
# AREA NAME        object
# Rpt Dist No       int64
# Part 1-2          int64
# Crm Cd            int64
# Crm Cd Desc      object
# Vict Age          int64
# Vict Sex         object
# Vict Descent     object
# Premis Cd       float64
# Premis Desc      object
# Status           object
# Status Desc      object
# Crm Cd 1        float64
# LOCATION         object
# LAT             float64
# LON             float64
# dtype: object

# %%
#update datatypes
df['Date Rptd'] = pd.to_datetime(df['Date Rptd'],format = '%Y %b %d %I:%M:%S %p')
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'],format = '%Y %b %d %I:%M:%S %p')
df
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004889  240710284 2024-07-24 2024-07-23      1400     7     Wilshire
# 1004890  240104953 2024-01-15 2024-01-15       100     1      Central
# 1004891  240410786 2024-10-14 2024-10-11      2330     4   Hollenbeck
# 1004892  240309674 2024-04-24 2024-04-24      1500     3    Southwest
# 1004893  240910892 2024-08-13 2024-08-12      2300     9     Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1502         2     354
# 1               1521         1     230
# 2                933         2     354
# 3                782         1     331
# 4               1454         1     420
# ...              ...       ...     ...
# 1004889          788         1     510
# 1004890          101         2     745
# 1004891          421         1     341
# 1004892          358         1     230
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  Vict Sex  \
# 0                                        THEFT OF IDENTITY  ...         M
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...         M
# 2                                        THEFT OF IDENTITY  ...         M
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...         F
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...         M
# ...                                                    ...  ...       ...
# 1004889                                   VEHICLE - STOLEN  ...       NaN
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...         X
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...         M
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...         F
# 1004893                                   VEHICLE - STOLEN  ...       NaN
#
#         Vict Descent Premis Cd             Premis Desc Status  Status Desc  \
# 0                  H     501.0  SINGLE FAMILY DWELLING     IC  Invest Cont
# 1                  H     102.0                SIDEWALK     IC  Invest Cont
# 2                  W     501.0  SINGLE FAMILY DWELLING     IC  Invest Cont
# 3                  A     101.0                  STREET     IC  Invest Cont
# 4                  H     103.0                   ALLEY     IC  Invest Cont
# ...              ...       ...                     ...    ...          ...
# 1004889          NaN     101.0                  STREET     IC  Invest Cont
# 1004890            X     503.0                   HOTEL     IC  Invest Cont
# 1004891            B     210.0    RESTAURANT/FAST FOOD     IC  Invest Cont
# 1004892            W     102.0                SIDEWALK     IC  Invest Cont
# 1004893          NaN     108.0             PARKING LOT     IC  Invest Cont
#
#         Crm Cd 1                                  LOCATION      LAT       LON
# 0          354.0   7800    BEEMAN                       AV  34.2124 -118.4092
# 1          230.0           ATOLL                        AV  34.1993 -118.4203
# 2          354.0  14600    SYLVAN                       ST  34.1847 -118.4509
# 3          331.0   6000    COMEY                        AV  34.0339 -118.3747
# 4          420.0                   4700    LA VILLA MARINA  33.9813 -118.4350
# ...          ...                                       ...      ...       ...
# 1004889    510.0   4000 W  23RD                         ST  34.0362 -118.3284
# 1004890    745.0   1300 W  SUNSET                       BL  34.0685 -118.2460
# 1004891    341.0   1700    ALBION                       ST  34.0675 -118.2240
# 1004892    230.0           FLOWER                       ST  34.0215 -118.2868
# 1004893    510.0   6900    VESPER                       AV  34.1961 -118.4510
#
# [1004894 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004894 entries, 0 to 1004893
# Data columns (total 21 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   DR_NO         1004894 non-null  int64
#  1   Date Rptd     1004894 non-null  datetime64[ns]
#  2   DATE OCC      1004894 non-null  datetime64[ns]
#  3   TIME OCC      1004894 non-null  int64
#  4   AREA          1004894 non-null  int64
#  5   AREA NAME     1004894 non-null  object
#  6   Rpt Dist No   1004894 non-null  int64
#  7   Part 1-2      1004894 non-null  int64
#  8   Crm Cd        1004894 non-null  int64
#  9   Crm Cd Desc   1004894 non-null  object
#  10  Vict Age      1004894 non-null  int64
#  11  Vict Sex      860263 non-null   object
#  12  Vict Descent  860251 non-null   object
#  13  Premis Cd     1004878 non-null  float64
#  14  Premis Desc   1004306 non-null  object
#  15  Status        1004893 non-null  object
#  16  Status Desc   1004894 non-null  object
#  17  Crm Cd 1      1004883 non-null  float64
#  18  LOCATION      1004894 non-null  object
#  19  LAT           1004894 non-null  float64
#  20  LON           1004894 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(7), object(8)
# memory usage: 161.0+ MB

# %%
df.describe(include = ['int64', 'float64'])
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.004894e+06  1.004894e+06  1.004894e+06  1.004894e+06  1.004894e+06
# mean   2.202190e+08  1.339901e+03  1.069153e+01  1.115613e+03  1.400313e+00
# std    1.319070e+07  6.510761e+02  6.110248e+00  6.111596e+02  4.899620e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106168e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209158e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311102e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521040e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd      Crm Cd 1           LAT  \
# count  1.004894e+06  1.004894e+06  1.004878e+06  1.004883e+06  1.004894e+06
# mean   5.001386e+02  2.891862e+01  3.056108e+02  4.998992e+02  3.399820e+01
# std    2.052638e+02  2.199267e+01  2.192913e+02  2.050643e+02  1.610789e+00
# min    1.100000e+02 -4.000000e+00  1.010000e+02  1.100000e+02  0.000000e+00
# 25%    3.310000e+02  0.000000e+00  1.010000e+02  3.310000e+02  3.401470e+01
# 50%    4.420000e+02  3.000000e+01  2.030000e+02  4.420000e+02  3.405890e+01
# 75%    6.260000e+02  4.400000e+01  5.010000e+02  6.260000e+02  3.416490e+01
# max    9.560000e+02  1.200000e+02  9.760000e+02  9.560000e+02  3.433430e+01
#
#                 LON
# count  1.004894e+06
# mean  -1.180908e+02
# std    5.582654e+00
# min   -1.186676e+02
# 25%   -1.184305e+02
# 50%   -1.183225e+02
# 75%   -1.182739e+02
# max    0.000000e+00

# %%
df['Vict Age'].value_counts()
# Out:
# Vict Age
#  0      269178
#  30      22288
#  35      21832
#  31      21419
#  29      21343
#          ...
#  98         71
# -2          28
# -3           6
# -4           3
#  120         1
# Name: count, Length: 104, dtype: int64

# %%
# Age should be greater than zero
df_age = df[df['Vict Age'] > 0]
df_age['Vict Age'].value_counts()
# Out:
# Vict Age
# 30     22288
# 35     21832
# 31     21419
# 29     21343
# 28     20969
#        ...
# 95       100
# 96        94
# 97        72
# 98        71
# 120        1
# Name: count, Length: 99, dtype: int64

# %%
df['Year'] = df['DATE OCC'].dt.year
df['Month'] = df['DATE OCC'].dt.month
df
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004889  240710284 2024-07-24 2024-07-23      1400     7     Wilshire
# 1004890  240104953 2024-01-15 2024-01-15       100     1      Central
# 1004891  240410786 2024-10-14 2024-10-11      2330     4   Hollenbeck
# 1004892  240309674 2024-04-24 2024-04-24      1500     3    Southwest
# 1004893  240910892 2024-08-13 2024-08-12      2300     9     Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1502         2     354
# 1               1521         1     230
# 2                933         2     354
# 3                782         1     331
# 4               1454         1     420
# ...              ...       ...     ...
# 1004889          788         1     510
# 1004890          101         2     745
# 1004891          421         1     341
# 1004892          358         1     230
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  Premis Cd  \
# 0                                        THEFT OF IDENTITY  ...      501.0
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      102.0
# 2                                        THEFT OF IDENTITY  ...      501.0
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...      101.0
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...      103.0
# ...                                                    ...  ...        ...
# 1004889                                   VEHICLE - STOLEN  ...      101.0
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...      503.0
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...      210.0
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      102.0
# 1004893                                   VEHICLE - STOLEN  ...      108.0
#
#                     Premis Desc Status  Status Desc Crm Cd 1  \
# 0        SINGLE FAMILY DWELLING     IC  Invest Cont    354.0
# 1                      SIDEWALK     IC  Invest Cont    230.0
# 2        SINGLE FAMILY DWELLING     IC  Invest Cont    354.0
# 3                        STREET     IC  Invest Cont    331.0
# 4                         ALLEY     IC  Invest Cont    420.0
# ...                         ...    ...          ...      ...
# 1004889                  STREET     IC  Invest Cont    510.0
# 1004890                   HOTEL     IC  Invest Cont    745.0
# 1004891    RESTAURANT/FAST FOOD     IC  Invest Cont    341.0
# 1004892                SIDEWALK     IC  Invest Cont    230.0
# 1004893             PARKING LOT     IC  Invest Cont    510.0
#
#                                          LOCATION      LAT       LON  Year  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092  2020
# 1                 ATOLL                        AV  34.1993 -118.4203  2020
# 2        14600    SYLVAN                       ST  34.1847 -118.4509  2020
# 3         6000    COMEY                        AV  34.0339 -118.3747  2020
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350  2020
# ...                                           ...      ...       ...   ...
# 1004889   4000 W  23RD                         ST  34.0362 -118.3284  2024
# 1004890   1300 W  SUNSET                       BL  34.0685 -118.2460  2024
# 1004891   1700    ALBION                       ST  34.0675 -118.2240  2024
# 1004892           FLOWER                       ST  34.0215 -118.2868  2024
# 1004893   6900    VESPER                       AV  34.1961 -118.4510  2024
#
#          Month
# 0           11
# 1           10
# 2           10
# 3           12
# 4            9
# ...        ...
# 1004889      7
# 1004890      1
# 1004891     10
# 1004892      4
# 1004893      8
#
# [1004894 rows x 23 columns]

# %%
df['Month'].value_counts()
# Out:
# Month
# 1     92675
# 3     87794
# 2     86357
# 10    84127
# 7     83962
# 8     83850
# 4     83517
# 5     83011
# 6     81382
# 9     81015
# 11    78978
# 12    78226
# Name: count, dtype: int64

# %%
# Line chart shows number of crimes in each month
df['Month'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df['Year'].value_counts().sort_index()
# Out:
# Year
# 2020    199847
# 2021    209876
# 2022    235259
# 2023    232345
# 2024    127567
# Name: count, dtype: int64

# %%
# Bar chart shows number of crimes in each year
df['Year'].value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Year'>

# %%
df = df[~((df['Month'] == '12') & (df['Year'] == '2023'))]
df
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004889  240710284 2024-07-24 2024-07-23      1400     7     Wilshire
# 1004890  240104953 2024-01-15 2024-01-15       100     1      Central
# 1004891  240410786 2024-10-14 2024-10-11      2330     4   Hollenbeck
# 1004892  240309674 2024-04-24 2024-04-24      1500     3    Southwest
# 1004893  240910892 2024-08-13 2024-08-12      2300     9     Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1502         2     354
# 1               1521         1     230
# 2                933         2     354
# 3                782         1     331
# 4               1454         1     420
# ...              ...       ...     ...
# 1004889          788         1     510
# 1004890          101         2     745
# 1004891          421         1     341
# 1004892          358         1     230
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  Premis Cd  \
# 0                                        THEFT OF IDENTITY  ...      501.0
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      102.0
# 2                                        THEFT OF IDENTITY  ...      501.0
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...      101.0
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...      103.0
# ...                                                    ...  ...        ...
# 1004889                                   VEHICLE - STOLEN  ...      101.0
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...      503.0
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...      210.0
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      102.0
# 1004893                                   VEHICLE - STOLEN  ...      108.0
#
#                     Premis Desc Status  Status Desc Crm Cd 1  \
# 0        SINGLE FAMILY DWELLING     IC  Invest Cont    354.0
# 1                      SIDEWALK     IC  Invest Cont    230.0
# 2        SINGLE FAMILY DWELLING     IC  Invest Cont    354.0
# 3                        STREET     IC  Invest Cont    331.0
# 4                         ALLEY     IC  Invest Cont    420.0
# ...                         ...    ...          ...      ...
# 1004889                  STREET     IC  Invest Cont    510.0
# 1004890                   HOTEL     IC  Invest Cont    745.0
# 1004891    RESTAURANT/FAST FOOD     IC  Invest Cont    341.0
# 1004892                SIDEWALK     IC  Invest Cont    230.0
# 1004893             PARKING LOT     IC  Invest Cont    510.0
#
#                                          LOCATION      LAT       LON  Year  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092  2020
# 1                 ATOLL                        AV  34.1993 -118.4203  2020
# 2        14600    SYLVAN                       ST  34.1847 -118.4509  2020
# 3         6000    COMEY                        AV  34.0339 -118.3747  2020
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350  2020
# ...                                           ...      ...       ...   ...
# 1004889   4000 W  23RD                         ST  34.0362 -118.3284  2024
# 1004890   1300 W  SUNSET                       BL  34.0685 -118.2460  2024
# 1004891   1700    ALBION                       ST  34.0675 -118.2240  2024
# 1004892           FLOWER                       ST  34.0215 -118.2868  2024
# 1004893   6900    VESPER                       AV  34.1961 -118.4510  2024
#
#          Month
# 0           11
# 1           10
# 2           10
# 3           12
# 4            9
# ...        ...
# 1004889      7
# 1004890      1
# 1004891     10
# 1004892      4
# 1004893      8
#
# [1004894 rows x 23 columns]

# %%
df.sort_values(by='DATE OCC')
# Out:
#             DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 70447   201404052 2020-01-01 2020-01-01       113    14      Pacific
# 124944  201307529 2020-03-03 2020-01-01      1200    13       Newton
# 194416  200116962 2020-08-26 2020-01-01      1450     1      Central
# 67762   230313075 2023-07-01 2020-01-01      1840     3    Southwest
# 151802  200304070 2020-01-01 2020-01-01      1530     3    Southwest
# ...           ...        ...        ...       ...   ...          ...
# 935705  241516179 2024-12-30 2024-12-30         1    15  N Hollywood
# 987419  250704070 2025-01-29 2024-12-30      1500     7     Wilshire
# 984779  241416055 2024-12-30 2024-12-30       945    14      Pacific
# 942143  240218331 2024-12-30 2024-12-30       645     2      Rampart
# 959580  240317263 2024-12-31 2024-12-30      1830     3    Southwest
#
#         Rpt Dist No  Part 1-2  Crm Cd  \
# 70447          1488         2     624
# 124944         1313         2     810
# 194416          182         2     354
# 67762           343         2     354
# 151802          303         2     624
# ...             ...       ...     ...
# 935705         1522         1     330
# 987419          719         2     649
# 984779         1494         2     888
# 942143          236         1     330
# 959580          327         1     510
#
#                                               Crm Cd Desc  ...  Premis Cd  \
# 70447                            BATTERY - SIMPLE ASSAULT  ...      503.0
# 124944  SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W...  ...      501.0
# 194416                                  THEFT OF IDENTITY  ...      502.0
# 67762                                   THEFT OF IDENTITY  ...      502.0
# 151802                           BATTERY - SIMPLE ASSAULT  ...      101.0
# ...                                                   ...  ...        ...
# 935705                              BURGLARY FROM VEHICLE  ...      101.0
# 987419                   DOCUMENT FORGERY / STOLEN FELONY  ...      602.0
# 984779                                        TRESPASSING  ...      212.0
# 942143                              BURGLARY FROM VEHICLE  ...      101.0
# 959580                                   VEHICLE - STOLEN  ...      121.0
#
#                                          Premis Desc Status  Status Desc  \
# 70447                                          HOTEL     AO  Adult Other
# 124944                        SINGLE FAMILY DWELLING     IC  Invest Cont
# 194416  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     IC  Invest Cont
# 67762   MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     IC  Invest Cont
# 151802                                        STREET     IC  Invest Cont
# ...                                              ...    ...          ...
# 935705                                        STREET     IC  Invest Cont
# 987419                                          BANK     IC  Invest Cont
# 984779             TRANSPORTATION FACILITY (AIRPORT)     IC  Invest Cont
# 942143                                        STREET     IC  Invest Cont
# 959580                   YARD (RESIDENTIAL/BUSINESS)     IC  Invest Cont
#
#        Crm Cd 1                                  LOCATION      LAT       LON  \
# 70447     624.0   9700    AIRPORT                      BL  33.9482 -118.3860
# 124944    810.0    900 E  20TH                         ST  34.0259 -118.2561
# 194416    354.0    600 W  9TH                          ST  34.0451 -118.2604
# 67762     354.0                      5400    VILLAGE GREE  34.0199 -118.3608
# 151802    624.0   2500 S  REDONDO                      BL  34.0339 -118.3557
# ...         ...                                       ...      ...       ...
# 935705    330.0  13000    LEMAY                        ST  34.1917 -118.4158
# 987419    649.0    500 N  LARCHMONT                    BL  34.0790 -118.3236
# 984779    888.0    200    WORLD                        WY  33.9455 -118.4003
# 942143    330.0                               BONNIE BRAE  34.0656 -118.2663
# 959580    510.0   1100 W  28TH                         ST  34.0294 -118.2840
#
#         Year  Month
# 70447   2020      1
# 124944  2020      1
# 194416  2020      1
# 67762   2020      1
# 151802  2020      1
# ...      ...    ...
# 935705  2024     12
# 987419  2024     12
# 984779  2024     12
# 942143  2024     12
# 959580  2024     12
#
# [1004894 rows x 23 columns]

# %%
df.groupby(['Year','Month']).size()
# Out:
# Year  Month
# 2020  1        18576
#       2        17284
#       3        16188
#       4        15706
#       5        17230
#       6        17060
#       7        17158
#       8        16902
#       9        15658
#       10       16510
#       11       15596
#       12       15979
# 2021  1        16636
#       2        15440
#       3        16354
#       4        16091
#       5        17020
#       6        17182
#       7        18690
#       8        18398
#       9        18386
#       10       19343
#       11       18374
#       12       17962
# 2022  1        18567
#       2        17750
#       3        19745
#       4        19837
#       5        20467
#       6        20273
#       7        20009
#       8        20144
#       9        19341
#       10       20335
#       11       18755
#       12       20036
# 2023  1        19970
#       2        18489
#       3        19214
#       4        18937
#       5        18908
#       6        18741
#       7        19935
#       8        20082
#       9        19321
#       10       20122
#       11       19074
#       12       19552
# 2024  1        18926
#       2        17394
#       3        16293
#       4        12946
#       5         9386
#       6         8126
#       7         8170
#       8         8324
#       9         8309
#       10        7817
#       11        7179
#       12        4697
# dtype: int64

# %%
# This line chart shows the number of crimes in each combination of month and year.
df.groupby(['Year','Month']).size().plot()
# Out:
# <Axes: xlabel='Year,Month'>

# %%
# The histogram shows the age distribution of criminals
plt.hist(df_age['Vict Age'], edgecolor = 'black', bins = 15)
plt.show()

# %%
# Crime count per day
crime_count_per_day = df.groupby(['DATE OCC', 'Crm Cd Desc']).size()
crime_count_per_day
# Out:
# DATE OCC    Crm Cd Desc
# 2020-01-01  ARSON                                                        4
#             ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              47
#             ATTEMPTED ROBBERY                                            5
#             BATTERY - SIMPLE ASSAULT                                    74
#             BATTERY ON A FIREFIGHTER                                     1
#                                                                         ..
# 2024-12-30  BURGLARY FROM VEHICLE                                        2
#             DOCUMENT FORGERY / STOLEN FELONY                             1
#             THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD     2
#             TRESPASSING                                                  1
#             VEHICLE - STOLEN                                             1
# Length: 92521, dtype: int64

# %%
# Top 20 crimes are
top_20_crimes = crime_count_per_day.groupby('Crm Cd Desc').mean().reset_index(name = 'average_daily_count')\
                 .sort_values(by = 'average_daily_count', ascending = False).head(20)
top_20_crimes
# Out:
#                                            Crm Cd Desc  average_daily_count
# 134                                   VEHICLE - STOLEN            63.392405
# 4                             BATTERY - SIMPLE ASSAULT            42.803776
# 21                               BURGLARY FROM VEHICLE            34.783680
# 116                                  THEFT OF IDENTITY            34.266301
# 131  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            33.471781
# 20                                            BURGLARY            32.862578
# 2       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT            30.725029
# 118                 THEFT PLAIN - PETTY ($950 & UNDER)            29.433425
# 74                   INTIMATE PARTNER - SIMPLE ASSAULT            28.448234
# 114    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            22.636164
# 113  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...            20.241096
# 123  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...            19.249179
# 100                                            ROBBERY            18.267383
# 105           SHOPLIFTING - PETTY THEFT ($950 & UNDER)            16.935890
# 132           VANDALISM - MISDEAMEANOR ($399 OR UNDER)            13.934102
# 38              CRIMINAL THREATS - NO WEAPON DISPLAYED            11.662432
# 129                                        TRESPASSING            10.179006
# 15                                     BRANDISH WEAPON             8.909871
# 73               INTIMATE PARTNER - AGGRAVATED ASSAULT             7.870647
# 137                     VIOLATION OF RESTRAINING ORDER             7.337914

# %%
top_20_crimes_sorted = top_20_crimes.sort_values(by = 'average_daily_count')
top_20_crimes_sorted
# Out:
#                                            Crm Cd Desc  average_daily_count
# 137                     VIOLATION OF RESTRAINING ORDER             7.337914
# 73               INTIMATE PARTNER - AGGRAVATED ASSAULT             7.870647
# 15                                     BRANDISH WEAPON             8.909871
# 129                                        TRESPASSING            10.179006
# 38              CRIMINAL THREATS - NO WEAPON DISPLAYED            11.662432
# 132           VANDALISM - MISDEAMEANOR ($399 OR UNDER)            13.934102
# 105           SHOPLIFTING - PETTY THEFT ($950 & UNDER)            16.935890
# 100                                            ROBBERY            18.267383
# 123  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...            19.249179
# 113  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...            20.241096
# 114    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            22.636164
# 74                   INTIMATE PARTNER - SIMPLE ASSAULT            28.448234
# 118                 THEFT PLAIN - PETTY ($950 & UNDER)            29.433425
# 2       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT            30.725029
# 20                                            BURGLARY            32.862578
# 131  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            33.471781
# 116                                  THEFT OF IDENTITY            34.266301
# 21                               BURGLARY FROM VEHICLE            34.783680
# 4                             BATTERY - SIMPLE ASSAULT            42.803776
# 134                                   VEHICLE - STOLEN            63.392405

# %%
# Horizontal bar chart of top 20 crimes
plt.barh(top_20_crimes_sorted['Crm Cd Desc'], top_20_crimes_sorted['average_daily_count'])
# Out:
# <BarContainer object of 20 artists>

# %%
# Formatting the plots
plt.style.available
plt.style.use('ggplot')

# %%
plt.figure(figsize = (12, 8))
# Line chart
plt.subplot(2,2,1)
crime_plot = df.groupby(['Year','Month']).size().plot(color = 'green', linewidth = 2)
crime_plot.set_xlabel('Year-Month', fontsize = 10)
crime_plot.set_title('Crime Over Time')

# Histogram
plt.subplot(2,2,2)
plt.hist(df_age['Vict Age'], edgecolor = 'black', bins = 15)
plt.xlabel('Age', fontsize = 10)
plt.title('Distribution of Victim Age')
plt.tight_layout()

# Horizontal bar chart
plt.figure()
plt.barh(top_20_crimes_sorted['Crm Cd Desc'], top_20_crimes_sorted['average_daily_count'], color = 'orange')
plt.title('Top 20 Crimes')
# Out:
# Text(0.5, 1.0, 'Top 20 Crimes')

# %%
# The time difference between crimes that occurred and those that were reported.”

# %%
df
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004889  240710284 2024-07-24 2024-07-23      1400     7     Wilshire
# 1004890  240104953 2024-01-15 2024-01-15       100     1      Central
# 1004891  240410786 2024-10-14 2024-10-11      2330     4   Hollenbeck
# 1004892  240309674 2024-04-24 2024-04-24      1500     3    Southwest
# 1004893  240910892 2024-08-13 2024-08-12      2300     9     Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1502         2     354
# 1               1521         1     230
# 2                933         2     354
# 3                782         1     331
# 4               1454         1     420
# ...              ...       ...     ...
# 1004889          788         1     510
# 1004890          101         2     745
# 1004891          421         1     341
# 1004892          358         1     230
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  Premis Cd  \
# 0                                        THEFT OF IDENTITY  ...      501.0
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      102.0
# 2                                        THEFT OF IDENTITY  ...      501.0
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...      101.0
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...      103.0
# ...                                                    ...  ...        ...
# 1004889                                   VEHICLE - STOLEN  ...      101.0
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...      503.0
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...      210.0
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      102.0
# 1004893                                   VEHICLE - STOLEN  ...      108.0
#
#                     Premis Desc Status  Status Desc Crm Cd 1  \
# 0        SINGLE FAMILY DWELLING     IC  Invest Cont    354.0
# 1                      SIDEWALK     IC  Invest Cont    230.0
# 2        SINGLE FAMILY DWELLING     IC  Invest Cont    354.0
# 3                        STREET     IC  Invest Cont    331.0
# 4                         ALLEY     IC  Invest Cont    420.0
# ...                         ...    ...          ...      ...
# 1004889                  STREET     IC  Invest Cont    510.0
# 1004890                   HOTEL     IC  Invest Cont    745.0
# 1004891    RESTAURANT/FAST FOOD     IC  Invest Cont    341.0
# 1004892                SIDEWALK     IC  Invest Cont    230.0
# 1004893             PARKING LOT     IC  Invest Cont    510.0
#
#                                          LOCATION      LAT       LON  Year  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092  2020
# 1                 ATOLL                        AV  34.1993 -118.4203  2020
# 2        14600    SYLVAN                       ST  34.1847 -118.4509  2020
# 3         6000    COMEY                        AV  34.0339 -118.3747  2020
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350  2020
# ...                                           ...      ...       ...   ...
# 1004889   4000 W  23RD                         ST  34.0362 -118.3284  2024
# 1004890   1300 W  SUNSET                       BL  34.0685 -118.2460  2024
# 1004891   1700    ALBION                       ST  34.0675 -118.2240  2024
# 1004892           FLOWER                       ST  34.0215 -118.2868  2024
# 1004893   6900    VESPER                       AV  34.1961 -118.4510  2024
#
#          Month
# 0           11
# 1           10
# 2           10
# 3           12
# 4            9
# ...        ...
# 1004889      7
# 1004890      1
# 1004891     10
# 1004892      4
# 1004893      8
#
# [1004894 rows x 23 columns]

# %%
df['Time to Rept'] = (pd.to_datetime(df['Date Rptd']) - pd.to_datetime(df['DATE OCC'])).dt.days

# %%
df
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004889  240710284 2024-07-24 2024-07-23      1400     7     Wilshire
# 1004890  240104953 2024-01-15 2024-01-15       100     1      Central
# 1004891  240410786 2024-10-14 2024-10-11      2330     4   Hollenbeck
# 1004892  240309674 2024-04-24 2024-04-24      1500     3    Southwest
# 1004893  240910892 2024-08-13 2024-08-12      2300     9     Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1502         2     354
# 1               1521         1     230
# 2                933         2     354
# 3                782         1     331
# 4               1454         1     420
# ...              ...       ...     ...
# 1004889          788         1     510
# 1004890          101         2     745
# 1004891          421         1     341
# 1004892          358         1     230
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  \
# 0                                        THEFT OF IDENTITY  ...
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...
# 2                                        THEFT OF IDENTITY  ...
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...
# ...                                                    ...  ...
# 1004889                                   VEHICLE - STOLEN  ...
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...
# 1004893                                   VEHICLE - STOLEN  ...
#
#                     Premis Desc Status  Status Desc  Crm Cd 1  \
# 0        SINGLE FAMILY DWELLING     IC  Invest Cont     354.0
# 1                      SIDEWALK     IC  Invest Cont     230.0
# 2        SINGLE FAMILY DWELLING     IC  Invest Cont     354.0
# 3                        STREET     IC  Invest Cont     331.0
# 4                         ALLEY     IC  Invest Cont     420.0
# ...                         ...    ...          ...       ...
# 1004889                  STREET     IC  Invest Cont     510.0
# 1004890                   HOTEL     IC  Invest Cont     745.0
# 1004891    RESTAURANT/FAST FOOD     IC  Invest Cont     341.0
# 1004892                SIDEWALK     IC  Invest Cont     230.0
# 1004893             PARKING LOT     IC  Invest Cont     510.0
#
#                                          LOCATION      LAT       LON  Year  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092  2020
# 1                 ATOLL                        AV  34.1993 -118.4203  2020
# 2        14600    SYLVAN                       ST  34.1847 -118.4509  2020
# 3         6000    COMEY                        AV  34.0339 -118.3747  2020
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350  2020
# ...                                           ...      ...       ...   ...
# 1004889   4000 W  23RD                         ST  34.0362 -118.3284  2024
# 1004890   1300 W  SUNSET                       BL  34.0685 -118.2460  2024
# 1004891   1700    ALBION                       ST  34.0675 -118.2240  2024
# 1004892           FLOWER                       ST  34.0215 -118.2868  2024
# 1004893   6900    VESPER                       AV  34.1961 -118.4510  2024
#
#         Month  Time to Rept
# 0          11           155
# 1          10             3
# 2          10          1502
# 3          12             0
# 4           9             4
# ...       ...           ...
# 1004889     7             1
# 1004890     1             0
# 1004891    10             3
# 1004892     4             0
# 1004893     8             1
#
# [1004894 rows x 24 columns]

# %%
df['Time to Rept'].value_counts()
# Out:
# Time to Rept
# 0       482015
# 1       222376
# 2        64436
# 3        37527
# 4        24121
#          ...
# 843          1
# 1387         1
# 1174         1
# 1628         1
# 935          1
# Name: count, Length: 1473, dtype: int64

# %%
df.groupby(['Crm Cd Desc'])['Time to Rept'].value_counts()
# Out:
# Crm Cd Desc                 Time to Rept
# ARSON                       0               1495
#                             1                497
#                             2                136
#                             3                 94
#                             4                 54
#                                             ...
# WEAPONS POSSESSION/BOMBING  2                  2
#                             4                  2
#                             42                 2
#                             3                  1
#                             354                1
# Name: count, Length: 15904, dtype: int64

# %%
df.groupby(['Crm Cd Desc'])['Time to Rept'].mean()\
    .reset_index(name = 'Average').sort_values(by = 'Average', ascending = True).head(10)
# Out:
#                                            Crm Cd Desc   Average
# 128                                     TRAIN WRECKING  0.000000
# 47                                      DISRUPT SCHOOL  0.076923
# 94                           PURSE SNATCHING - ATTEMPT  0.076923
# 88                           PETTY THEFT - AUTO REPAIR  0.125000
# 80                                            LYNCHING  0.136364
# 64            FIREARMS RESTRAINING ORDER (FIREARMS RO)  0.250000
# 6                              BATTERY POLICE (SIMPLE)  0.358285
# 98   REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR D...  0.384615
# 63   FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS ...  0.400000
# 14                                          BOMB SCARE  0.490446

# %%
# The top 3 crimes with the highest average victim age
df_age['Vict Age']
# Out:
# 0          31
# 1          32
# 2          30
# 3          47
# 4          63
#            ..
# 1004885    42
# 1004887    36
# 1004888    46
# 1004891    29
# 1004892    70
# Name: Vict Age, Length: 735579, dtype: int64

# %%
df_age.groupby('Crm Cd Desc')['Vict Age'].mean().reset_index()\
    .sort_values(by = 'Vict Age',ascending = False).head(3)
# Out:
#                            Crm Cd Desc   Vict Age
# 45  DISHONEST EMPLOYEE ATTEMPTED THEFT  60.000000
# 54                DRUNK ROLL - ATTEMPT  58.000000
# 12      BLOCKING DOOR INDUCTION CENTER  54.666667

# %%
# The areas in which highest number of crimes occuring during night time

# %%
df['TIME OCC'] = pd.to_datetime(df['TIME OCC'].astype(str).str.zfill(4), format='%H%M').dt.time

# %%
nighttime_crimes = df[(df['TIME OCC'].apply(lambda t: t.hour) >= 20)\
    | (df['TIME OCC'].apply(lambda t: t.hour) <= 3)]
nighttime_crimes
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA   AREA NAME  \
# 10       240605846 2024-02-06 2020-06-20  00:01:00     6   Hollywood
# 14       201406733 2020-02-16 2020-02-13  23:00:00    14     Pacific
# 27       201915689 2020-10-15 2020-10-15  03:05:00    19     Mission
# 29       202013248 2020-08-09 2020-08-09  22:50:00    20     Olympic
# 31       201811813 2020-05-28 2020-05-25  02:00:00    18   Southeast
# ...            ...        ...        ...       ...   ...         ...
# 1004885  240119644 2024-10-04 2024-09-27  23:45:00     1     Central
# 1004887  242011172 2024-08-20 2024-08-17  23:00:00    20     Olympic
# 1004890  240104953 2024-01-15 2024-01-15  01:00:00     1     Central
# 1004891  240410786 2024-10-14 2024-10-11  23:30:00     4  Hollenbeck
# 1004893  240910892 2024-08-13 2024-08-12  23:00:00     9    Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 10               657         2     812
# 14              1406         1     330
# 27              1918         2     740
# 29              2069         2     626
# 31              1851         1     510
# ...              ...       ...     ...
# 1004885          142         1     440
# 1004887         2033         1     341
# 1004890          101         2     745
# 1004891          421         1     341
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  \
# 10       CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...  ...
# 14                                   BURGLARY FROM VEHICLE  ...
# 27       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...
# 29                       INTIMATE PARTNER - SIMPLE ASSAULT  ...
# 31                                        VEHICLE - STOLEN  ...
# ...                                                    ...  ...
# 1004885                 THEFT PLAIN - PETTY ($950 & UNDER)  ...
# 1004887  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...
# 1004893                                   VEHICLE - STOLEN  ...
#
#                                           Premis Desc Status   Status Desc  \
# 10                             SINGLE FAMILY DWELLING     AA  Adult Arrest
# 14                                     GARAGE/CARPORT     IC   Invest Cont
# 27                                        PARKING LOT     IC   Invest Cont
# 29       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     AA  Adult Arrest
# 31                                             STREET     IC   Invest Cont
# ...                                               ...    ...           ...
# 1004885                      VEHICLE, PASSENGER/TRUCK     IC   Invest Cont
# 1004887                        BAR/COCKTAIL/NIGHTCLUB     IC   Invest Cont
# 1004890                                         HOTEL     IC   Invest Cont
# 1004891                          RESTAURANT/FAST FOOD     IC   Invest Cont
# 1004893                                   PARKING LOT     IC   Invest Cont
#
#          Crm Cd 1                                  LOCATION      LAT  \
# 10          812.0   1000 N  RIDGEWOOD                    PL  34.0878
# 14          330.0   3300    MOTOR                        AV  34.0240
# 27          740.0  13600    FOOTHILL                     BL  34.3069
# 29          626.0   1200 S  WESTMORELAND                 AV  34.0495
# 31          510.0           MENLO                        AV  33.9144
# ...           ...                                       ...      ...
# 1004885     440.0                                    W  3RD  34.0531
# 1004887     341.0   3700    WILSHIRE                     BL  34.0617
# 1004890     745.0   1300 W  SUNSET                       BL  34.0685
# 1004891     341.0   1700    ALBION                       ST  34.0675
# 1004893     510.0   6900    VESPER                       AV  34.1961
#
#               LON  Year Month  Time to Rept
# 10      -118.3146  2020     6          1326
# 14      -118.4090  2020     2             3
# 27      -118.4297  2020    10             0
# 29      -118.2891  2020     8             0
# 31      -118.2894  2020     5             3
# ...           ...   ...   ...           ...
# 1004885 -118.2512  2024     9             7
# 1004887 -118.3066  2024     8             3
# 1004890 -118.2460  2024     1             0
# 1004891 -118.2240  2024    10             3
# 1004893 -118.4510  2024     8             1
#
# [316145 rows x 24 columns]

# %%
df
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07  08:45:00    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18  18:45:00    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30  12:40:00     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24  13:10:00     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29  18:30:00    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004889  240710284 2024-07-24 2024-07-23  14:00:00     7     Wilshire
# 1004890  240104953 2024-01-15 2024-01-15  01:00:00     1      Central
# 1004891  240410786 2024-10-14 2024-10-11  23:30:00     4   Hollenbeck
# 1004892  240309674 2024-04-24 2024-04-24  15:00:00     3    Southwest
# 1004893  240910892 2024-08-13 2024-08-12  23:00:00     9     Van Nuys
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1502         2     354
# 1               1521         1     230
# 2                933         2     354
# 3                782         1     331
# 4               1454         1     420
# ...              ...       ...     ...
# 1004889          788         1     510
# 1004890          101         2     745
# 1004891          421         1     341
# 1004892          358         1     230
# 1004893          914         1     510
#
#                                                Crm Cd Desc  ...  \
# 0                                        THEFT OF IDENTITY  ...
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...
# 2                                        THEFT OF IDENTITY  ...
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...
# ...                                                    ...  ...
# 1004889                                   VEHICLE - STOLEN  ...
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...
# 1004893                                   VEHICLE - STOLEN  ...
#
#                     Premis Desc Status  Status Desc  Crm Cd 1  \
# 0        SINGLE FAMILY DWELLING     IC  Invest Cont     354.0
# 1                      SIDEWALK     IC  Invest Cont     230.0
# 2        SINGLE FAMILY DWELLING     IC  Invest Cont     354.0
# 3                        STREET     IC  Invest Cont     331.0
# 4                         ALLEY     IC  Invest Cont     420.0
# ...                         ...    ...          ...       ...
# 1004889                  STREET     IC  Invest Cont     510.0
# 1004890                   HOTEL     IC  Invest Cont     745.0
# 1004891    RESTAURANT/FAST FOOD     IC  Invest Cont     341.0
# 1004892                SIDEWALK     IC  Invest Cont     230.0
# 1004893             PARKING LOT     IC  Invest Cont     510.0
#
#                                          LOCATION      LAT       LON  Year  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092  2020
# 1                 ATOLL                        AV  34.1993 -118.4203  2020
# 2        14600    SYLVAN                       ST  34.1847 -118.4509  2020
# 3         6000    COMEY                        AV  34.0339 -118.3747  2020
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350  2020
# ...                                           ...      ...       ...   ...
# 1004889   4000 W  23RD                         ST  34.0362 -118.3284  2024
# 1004890   1300 W  SUNSET                       BL  34.0685 -118.2460  2024
# 1004891   1700    ALBION                       ST  34.0675 -118.2240  2024
# 1004892           FLOWER                       ST  34.0215 -118.2868  2024
# 1004893   6900    VESPER                       AV  34.1961 -118.4510  2024
#
#         Month  Time to Rept
# 0          11           155
# 1          10             3
# 2          10          1502
# 3          12             0
# 4           9             4
# ...       ...           ...
# 1004889     7             1
# 1004890     1             0
# 1004891    10             3
# 1004892     4             0
# 1004893     8             1
#
# [1004894 rows x 24 columns]

# %%
nighttime_crimes['AREA NAME'].value_counts()
# Out:
# AREA NAME
# Central        22367
# 77th Street    20307
# Hollywood      18348
# Pacific        18179
# Southwest      17686
# Southeast      16840
# Olympic        16568
# N Hollywood    15992
# Newton         15953
# Rampart        15010
# Wilshire       13861
# Harbor         13627
# Northeast      13393
# West Valley    13287
# Van Nuys       12885
# Mission        12837
# West LA        12633
# Devonshire     12111
# Hollenbeck     12100
# Topanga        11910
# Foothill       10251
# Name: count, dtype: int64

# %%
hourly_occ = df['TIME OCC'].apply(lambda t: t.hour).value_counts().sort_index().reset_index(name = 'count')
hourly_occ
# Out:
#     TIME OCC  count
# 0          0  40467
# 1          1  29760
# 2          2  25214
# 3          3  22190
# 4          4  18756
# 5          5  17288
# 6          6  23184
# 7          7  26264
# 8          8  37243
# 9          9  36519
# 10        10  43020
# 11        11  43663
# 12        12  67806
# 13        13  45572
# 14        14  49295
# 15        15  52811
# 16        16  52968
# 17        17  58809
# 18        18  59955
# 19        19  55596
# 20        20  56349
# 21        21  50788
# 22        22  49100
# 23        23  42277

# %%
# Bar chart shows the hourly occurance of crimes
plt.bar(hourly_occ['TIME OCC'], hourly_occ['count'])
# Out:
# <BarContainer object of 24 artists>

# %%
# Maximum number of crimes occuring at 12 o’clock
df[df['TIME OCC'].apply(lambda t: t.hour) == 12]['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# THEFT OF IDENTITY                               10381
# VEHICLE - STOLEN                                 5102
# THEFT PLAIN - PETTY ($950 & UNDER)               4703
# BATTERY - SIMPLE ASSAULT                         4373
# BURGLARY                                         3285
#                                                 ...
# DRUGS, TO A MINOR                                   1
# THEFT, COIN MACHINE - GRAND ($950.01 & OVER)        1
# BIGAMY                                              1
# BRIBERY                                             1
# INCITING A RIOT                                     1
# Name: count, Length: 123, dtype: int64

# %%
no_identity_theft = df[~(df['Crm Cd Desc'] == 'THEFT OF IDENTITY')]

# %%
new_hourly_occ = no_identity_theft['TIME OCC'].apply(lambda t: t.hour).value_counts().sort_index().reset_index(name = 'count')

# %%
plt.bar(new_hourly_occ['TIME OCC'], new_hourly_occ['count'])
# Out:
# <BarContainer object of 24 artists>

# %%
no_identity_theft[no_identity_theft['TIME OCC'].apply(lambda t: t.hour) == 12]['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                            5102
# THEFT PLAIN - PETTY ($950 & UNDER)                          4703
# BATTERY - SIMPLE ASSAULT                                    4373
# BURGLARY                                                    3285
# THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD    3141
#                                                             ...
# DRUGS, TO A MINOR                                              1
# THEFT, COIN MACHINE - GRAND ($950.01 & OVER)                   1
# BIGAMY                                                         1
# BRIBERY                                                        1
# INCITING A RIOT                                                1
# Name: count, Length: 122, dtype: int64
